# %%
import matplotlib.pyplot as plt

plt.plot(3, 4, 'o')
plt.plot(2,4, 's')

# %%
plt.plot(1, 2, 'ro', label='Data A')
plt.plot(2, -1, 'bp', markersize=10, label='Data 2')
plt.legend()
plt.show()

# %%
plt.plot([0,1], [0,2], 'ms-')
plt.show()

# %%
import numpy as np

# x = np.linspace(0,3*)

# %%
x = np.linspace(0, 3*np.pi, 1001)
y = np.sin(x)

plt.plot(x, y, 'k', label='A pretty sine wave')
plt.legend()
plt.show()
