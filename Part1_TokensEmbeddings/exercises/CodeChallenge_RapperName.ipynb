# %%
# typical libraries...
import numpy as np

# for importing and working with texts
import requests
import re
import string

import matplotlib.pyplot as plt

import tiktoken

# %%
name = "Robert Cowher Grey"
name_list = name.split()

first_letter = name_list[0][0]
last_letter = name_list[1][-1]


print(first_letter)
print(last_letter)
# Out:
# R
# r

# %%
tokenizer = tiktoken.get_encoding('cl100k_base')

# %%
string_tokens = tokenizer.encode(name)
first_letter_tokens = tokenizer.encode(first_letter)
last_letter_tokens = tokenizer.encode(last_letter)



tokens = sorted(tokens)

print(tokens)
# Out:
# [1964, 22607, 26769, 35632]
